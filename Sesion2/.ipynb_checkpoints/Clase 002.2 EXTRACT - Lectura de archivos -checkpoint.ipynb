# %% [markdown]
# <img src="https://fotos.subefotos.com/bfa0edacd915cdc7de8ee4a357071610o.png" style = "width: 150px; height: auto; margin-left:auto;margin-right:auto"/>
# <img src="https://fotos.subefotos.com/2a13aea56c4bf96860ed297b29abc189o.png" style = "width: 750px; height: auto; margin-left: auto; margin-right: auto;margin-top:0 "/>

# %% [markdown]
# ## EXTRACT - Lectura de archivos

# %% [markdown]
# Queremos obtener una lista de datos en texto plano, supongamos que queremos obtener los números de billetes de los ganadaroes de "la rifa del avión presidencial" vistas en [El financiero](https://elfinanciero.com.mx/nacional/estos-son-los-ganadores-de-la-rifa-del-avion-presidencial).

# %% [markdown]
# Podemos hacerlo de dos maneras. La primera consiste en copia y pegar esa lista directamente en una variable, pero puede causar inconvenientes ya que ocuparía mucho espacio de nuestro script.

# %%
boletos = """1. 5349161

2. 1568335

3. 3432705

4. 3752399

5. 5851982

6. 0965969

7. 2818612

8. 1167320

9. 1060378

10. 2574928

...

95. 2431759

96. 0168420

97. 1735539

98. 0914804

99. 5276341

100. 5770061"""

# %%
boletos
# Out:
# '1. 5349161\n\n2. 1568335\n\n3. 3432705\n\n4. 3752399\n\n5. 5851982\n\n6. 0965969\n\n7. 2818612\n\n8. 1167320\n\n9. 1060378\n\n10. 2574928\n\n11. 1285450\n\n12. 2830132\n\n13. 1636562\n\n14. 5732907\n\n15. 1311697\n\n16.0661866\n\n17. 4250772\n\n18. 4344899\n\n19. 4893246\n\n20. 1163272\n\n21. 0703063\n\n22. 4718493\n\n23. 3310202\n\n24. 0946316\n\n25. 2390902\n\n26. 1792015\n\n27. 5407604\n\n28. 5652051\n\n29. 4569761\n\n30. 4642362\n\n31. 4257343\n\n32. 1964762\n\n33. 2780075\n\n34. 1355167\n\n35. 3056503\n\n36. 0359742\n\n37. 4300072\n\n38. 2746989\n\n39. 3399642\n\n40. 1891786\n\n41. 2953199\n\n42. 2887316\n\n43. 4690815\n\n44. 5578067\n\n45. 1590540\n\n46. 5191096\n\n47. 5875151\n\n48. 3158414\n\n49. 5352100\n\n50. 3096144\n\n51. 1815455\n\n52. 1375232\n\n53. 1490637\n\n54. 1249213\n\n55. 5242187\n\n56. 2782163\n\n57. 3199483\n\n58. 3031137\n\n59. 5819530\n\n60. 5943830\n\n61. 2972445\n\n62. 2485236\n\n63. 4867873\n\n64. 3593502\n\n65. 1355690\n\n66. 2634845\n\n67. 2608938\n\n68
# ...

# %% [markdown]
# Por eso es que optamos por la segunda opción: Copiar toda la lista en un archivo de texto plano *.txt*

# %% [markdown]
# ### Para leer archivos desde Google Drive (por el momento solo para los que utilizan Google Colab)
# Se tiene que importar una librería para leer archivos de nuestro Google drive. Subir el archivo txt a nuestro Drive y buscarlo

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Para Jupyter Notebook
# Nosotros ya creamos el archivo, puede hacerlo tu desde *bloc de notas* o desde la terminal.

# %%
with open('boletos.txt') as f: 
    boletos = f.readlines()

# %%
boletos
# Out:
# ['\n',
#  '1. 5349161\n',
#  '\n',
#  '2. 1568335\n',
#  '\n',
#  '3. 3432705\n',
#  '\n',
#  '4. 3752399\n',
#  '\n',
#  '5. 5851982\n',
#  '\n',
#  '6. 0965969\n',
#  '\n',
#  '7. 2818612\n',
#  '\n',
#  '8. 1167320\n',
#  '\n',
#  '9. 1060378\n',
#  '\n',
#  '10. 2574928\n',
#  '\n',
#  '11. 1285450\n',
#  '\n',
#  '12. 2830132\n',
#  '\n',
#  '13. 1636562\n',
#  '\n',
#  '14. 5732907\n',
#  '\n',
#  '15. 1311697\n',
#  '\n',
#  '16.0661866\n',
#  '\n',
#  '17. 4250772\n',
#  '\n',
#  '18. 4344899\n',
#  '\n',
#  '19. 4893246\n',
#  '\n',
#  '20. 1163272\n',
#  '\n',
#  '21. 0703063\n',
#  '\n',
#  '22. 4718493\n',
#  '\n',
#  '23. 3310202\n',
#  '\n',
#  '24. 0946316\n',
#  '\n',
#  '25. 2390902\n',
#  '\n',
#  '26. 1792015\n',
#  '\n',
#  '27. 5407604\n',
#  '\n',
#  '28. 5652051\n',
#  '\n',
#  '29. 4569761\n',
#  '\n',
#  '30. 4642362\n',
#  '\n',
#  '31. 4257343\n',
#  '\n',
#  '32. 1964762\n',
#  '\n',
#  '33. 2780075\n',
#  '\n',
#  '34. 1355167\n',
#  '\n',
# ...

# %% [markdown]
# ### Actividad 1
# Crea una función que extraiga solo los números de boletos de la variable anterior *boletos*. Después cargalos a una serie de Pandas.

# %%
def actividad1(boletos):
    '''
    Aquí empieza a escribir la actividad. 
    '''
    return 0

# %% [markdown]
# ## Actividad 2 (guíada)
#
# Hemos creado un archivo de texto plano *university_towns.txt* que contiene la lista de pueblos con universidades en Estados Unidos, fue extraido de [wikipedia](https://en.wikipedia.org/wiki/List_of_college_towns#College_towns_in_the_United_States).
#
# Organiza los datos.

# %%
with open('university_towns.txt') as f: 
    pueblos = f.readlines()

# %%
pueblos
# Out:
# ['Alabama[edit]\n',
#  'Auburn (Auburn University)[1]\n',
#  'Florence (University of North Alabama)\n',
#  'Jacksonville (Jacksonville State University)[2]\n',
#  'Livingston (University of West Alabama)[2]\n',
#  'Montevallo (University of Montevallo)[2]\n',
#  'Troy (Troy University)[2]\n',
#  'Tuscaloosa (University of Alabama, Stillman College, Shelton State)[3][4]\n',
#  'Tuskegee (Tuskegee University)[5]\n',
#  'Alaska[edit]\n',
#  'Fairbanks (University of Alaska Fairbanks)[2]\n',
#  'Arizona[edit]\n',
#  'Flagstaff (Northern Arizona University)[6]\n',
#  'Tempe (Arizona State University)\n',
#  'Tucson (University of Arizona)\n',
#  'Arkansas[edit]\n',
#  'Arkadelphia (Henderson State University, Ouachita Baptist University)[2]\n',
#  'Conway (Central Baptist College, Hendrix College, University of Central Arkansas)[2]\n',
#  'Fayetteville (University of Arkansas)[7]\n',
#  'Jonesboro (Arkansas State University)[8]\n',
#  'Magnolia (Southern Arkansas University)[2]\n',
# ...
